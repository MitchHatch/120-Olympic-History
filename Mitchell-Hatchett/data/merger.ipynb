# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
athlete_df = pd.read_csv ("athlete_events.csv")
noc_regions_df = pd.read_csv("noc_regions.csv")
world_cities_df = pd.read_csv('worldcities.csv')

# %%
athlete_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
athlete_df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
athlete_clean_up = athlete_df.rename(columns={"Team":"Country"})
athlete_clean_up.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Country  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
athlete_clean_up.count()
# Out:
# ID         271116
# Name       271116
# Sex        271116
# Age        261642
# Height     210945
# Weight     208241
# Country    271116
# NOC        271116
# Games      271116
# Year       271116
# Season     271116
# City       271116
# Sport      271116
# Event      271116
# Medal       39783
# dtype: int64

# %%
athlete_clean_up.count()
# Out:
# ID         271116
# Name       271116
# Sex        271116
# Age        261642
# Height     210945
# Weight     208241
# Country    271116
# NOC        271116
# Games      271116
# Year       271116
# Season     271116
# City       271116
# Sport      271116
# Event      271116
# Medal       39783
# dtype: int64

# %%
athlete_clean_up.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Country  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
athlete_clean_up.reset_index()
# Out:
#          index      ID                      Name Sex   Age  Height  Weight  \
# 0            0       1                 A Dijiang   M  24.0   180.0    80.0
# 1            1       2                  A Lamusi   M  23.0   170.0    60.0
# 2            2       3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            3       4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            4       5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...     ...                       ...  ..   ...     ...     ...
# 271111  271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
# ...

# %%
athlete_by_year = athlete_clean_up.sort_values(by=['Year','Country'])
athlete_by_year.head()
# Out:
#           ID                        Name Sex   Age  Height  Weight  \
# 70079  35698  Edwin Harold "Teddy" Flack   M  22.0     NaN     NaN
# 70081  35698  Edwin Harold "Teddy" Flack   M  22.0     NaN     NaN
# 70082  35698  Edwin Harold "Teddy" Flack   M  22.0     NaN     NaN
# 70083  35698  Edwin Harold "Teddy" Flack   M  22.0     NaN     NaN
# 70080  35698  Edwin Harold "Teddy" Flack   M  22.0     NaN     NaN
#
#                        Country  NOC        Games  Year  Season    City  \
# 70079                Australia  AUS  1896 Summer  1896  Summer  Athina
# 70081                Australia  AUS  1896 Summer  1896  Summer  Athina
# 70082                Australia  AUS  1896 Summer  1896  Summer  Athina
# 70083                Australia  AUS  1896 Summer  1896  Summer  Athina
# 70080  Australia/Great Britain  AUS  1896 Summer  1896  Summer  Athina
#
#            Sport                         Event   Medal
# 70079     Tennis          Tennis Men's Singles     NaN
# ...

# %%
world_cities_df.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6897  139.6922      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37732000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
world_cities_df = world_cities_df.drop(columns=['iso2','iso3','admin_name','id','population','city_ascii','capital'])

# %%
world_clean_up_df = world_cities_df.rename(columns={"country":"Country", 'city':'City'})
world_clean_up_df.head()
# Out:
#         City      lat       lng    Country
# 0      Tokyo  35.6897  139.6922      Japan
# 1    Jakarta  -6.1750  106.8275  Indonesia
# 2      Delhi  28.6100   77.2300      India
# 3  Guangzhou  23.1300  113.2600      China
# 4     Mumbai  19.0761   72.8775      India

# %%
merged_df = pd.merge(athlete_by_year,world_clean_up_df, on = ['Country','City'])
merged_df.head()
# Out:
#       ID                         Name Sex   Age  Height  Weight Country  NOC  \
# 0  42414  Alexander "Alex" Grant, Jr.   M  26.0     NaN     NaN  Canada  CAN
# 1  42414  Alexander "Alex" Grant, Jr.   M  26.0     NaN     NaN  Canada  CAN
# 2  42424         Richard "Dick" Grant   M  21.0     NaN     NaN  Canada  CAN
# 3  72887        Ronald John MacDonald   M  25.0   170.0    64.0  Canada  CAN
# 4  89626   George Washington F. Orton   M  27.0   169.0    65.0  Canada  CAN
#
#          Games  Year  Season   City      Sport  \
# 0  1900 Summer  1900  Summer  Paris  Athletics
# 1  1900 Summer  1900  Summer  Paris  Athletics
# 2  1900 Summer  1900  Summer  Paris  Athletics
# 3  1900 Summer  1900  Summer  Paris  Athletics
# 4  1900 Summer  1900  Summer  Paris  Athletics
#
#                                        Event   Medal   lat      lng
# 0                 Athletics Men's 800 metres     NaN  43.2 -80.3833
# 1  Athletics Men's 4,000 metres Steeplechase     NaN  43.2 -80.3833
# ...

# %%
merged_df1 = merged_df.sort_values(by=['Country'])
merged_df1.head()
merged_df1.to_json('sorted_merged_data.geojson', orient='records')

# %%
age_groups = merged_df1.groupby(by= "Age")
age_groups

# %%
country_count = merged_df1.Country.value_counts()
plt.figure(figsize=(18,9))
plt.title('Countries in Olympics')
plt.pie(country_count,labels = country_count.index,autopct ='%1.1f%%',startangle =180,shadow ='True' )
# Out:
# ([<matplotlib.patches.Wedge at 0x15c52d22c10>,
# ...
#  [Text(-0.13749101846724085, -1.0913735473433654, 'United States'),
#   Text(1.0998869538113085, 0.01576987113709846, 'France'),
#   Text(0.9546007836482474, 0.5465687000351852, 'Australia'),
#   Text(0.6277808281724729, 0.9032669770223443, 'Canada'),
#   Text(0.2936214652003254, 1.0600879374719883, 'Japan'),
#   Text(0.017995918217261327, 1.0998527842068309, 'China'),
#   Text(-0.22893279029897406, 1.0759134619131439, 'Sweden'),
#   Text(-0.4410511178077857, 1.007707254851578, 'Brazil'),
#   Text(-0.6251883596616508, 0.905063265713273, 'Germany'),
#   Text(-0.7819390531331746, 0.7736739088176585, 'Spain'),
#   Text(-0.8989040942704387, 0.634012168103927, 'Mexico'),
#   Text(-0.9798459494809767, 0.4999019056632246, 'Finland'),
#   Text(-1.0364600150470813, 0.36844353327016655, 'Netherlands'),
#   Text(-1.0722316639399665, 0.2455997940645122, 'Russia'),
#   Text(-1.0907360997825477, 0.14245968072109486, 'Norway'),
# ...
